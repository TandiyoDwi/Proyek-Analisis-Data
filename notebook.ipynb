# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Tandiyo Dwi Oktavian]
# - **Email:** [tndiodwi@gmail.com]
# - **ID Dicoding:** [MC378D5Y0833]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 Total Penyewaan Sepeda Berdasarkan Musim berdasarkan pelanggan Casual dan Registered
# - Pertanyaan 2 Total Penyewaan Sepeda pada Tahun 2011 - 2012

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#Membaca data dari file day.csv dan hour.csv

# %%
day_df = pd.read_csv('data/day.csv', delimiter=',')
hour_df = pd.read_csv('data/hour.csv', delimiter=',')

# %%
# Menampilkan data day.csv

# %%
day_df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %%
#Menampilkan data hour.csv

# %%
hour_df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %% [markdown]
# **Insight:**
# - Tabel Day menampung data sebanyak 732 hari
# - Tabel Hour menampung data sebanyak 17380 jam

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ##### Menilai Data day.csv

# %%
#Mencari data day.csv yang duplicate

# %%
day_duplicates = day_df.duplicated().sum()

# %%
#Menacritahu tipe data day.csv

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#Assessing Data day.csv

# %%
day_df = pd.read_csv("data/day.csv")
day_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#descriptive data day.csv

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# ##### Menilai Data hour.csv

# %%
#Mencari data day.csv yang duplicate

# %%
hour_duplicates = hour_df.duplicated().sum()

# %%
#Menacritahu tipe data day.csv

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
#Assessing Data hour.csv

# %%
hour_df = pd.read_csv("data/hour.csv")
hour_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#descriptive data hour.csv

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - Tidak terdapat missing value pada data day.cvs dan hour.csv
# - Tidak ada baris yang sama pada kedua data
# - value dari season harus sesaui dengan nama musim
# - value dari weekdays harus sesuai dengan hari dalam seminggu

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# 1. Menghapus data hour.cvs karena tidak dibutuhkan dalam pertanyaan bisnis yg saya tetapkan, tabel hour dan day itu bedanya hanya di kolom hrnya saja, selebihnya sama semua.

# %%
del hour_df

# %% [markdown]
# 2. Mengubah data kolom pada season menjadi string

# %%
day_df['season'] = day_df['season'].map({
    1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'
})
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01  Spring   0     1        0        6           0
# 1        2  2011-01-02  Spring   0     1        0        0           0
# 2        3  2011-01-03  Spring   0     1        0        1           1
# 3        4  2011-01-04  Spring   0     1        0        2           1
# 4        5  2011-01-05  Spring   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# 3. Mengubah data year menjadi tahun 2011 dan 2012

# %%
day_df['yr'] = day_df['yr'].map({
    0: '2011', 1: '2012',
})
day_df.head()
# Out:
#    instant      dteday  season    yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01  Spring  2011     1        0        6           0
# 1        2  2011-01-02  Spring  2011     1        0        0           0
# 2        3  2011-01-03  Spring  2011     1        0        1           1
# 3        4  2011-01-04  Spring  2011     1        0        2           1
# 4        5  2011-01-05  Spring  2011     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day_df['season'] = day_df.season.astype('category')
day_df['yr'] = day_df.yr.astype('category')
day_df.head()
# Out:
#    instant      dteday  season    yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01  Spring  2011     1        0        6           0
# 1        2  2011-01-02  Spring  2011     1        0        0           0
# 2        3  2011-01-03  Spring  2011     1        0        1           1
# 3        4  2011-01-04  Spring  2011     1        0        2           1
# 4        5  2011-01-05  Spring  2011     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    category
#  3   yr          731 non-null    category
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: category(2), float64(4), int64(9), object(1)
# memory usage: 81.8+ KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Pengelompokan data day.csv

# %% [markdown]
# Pengelompokan berdasarkan musim

# %%
day_df.groupby(by='season', observed=True).agg({
    'casual': 'mean',
    'registered': 'mean',
    'cnt': ['max', 'min', 'mean']
})
# Out:
#              casual   registered   cnt
#                mean         mean   max   min         mean
# season
# Fall    1202.611702  4441.691489  8714  1115  5644.303191
# Spring   334.928177  2269.204420  7836   431  2604.132597
# Summer  1106.097826  3886.233696  8362   795  4992.331522
# Winter   729.112360  3999.050562  8555    22  4728.162921

# %% [markdown]
# Pengelompokan berdasarkan penyewaan pertahun

# %%
day_df.groupby(by='yr', observed=True).agg({
    'casual': 'mean',  
    'registered': 'mean',
    'cnt': ['max', 'min', 'mean']
})
# Out:
#            casual   registered   cnt
#              mean         mean   max  min         mean
# yr
# 2011   677.402740  2728.358904  6043  431  3405.761644
# 2012  1018.483607  4581.450820  8714   22  5599.934426

# %% [markdown]
# **Insight:**
# - Penyewaan sepeda terbanyak terdapat pada musim Falls
# - Penyewaan paling banyak terdapat pada tahun 2012 dibandingkan dengan tahun 2011

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
#Penyewaan Sepeda Tiap Musim
season_usage = day_df.groupby("season", observed=False)[["registered", "casual"]].sum().reset_index()

plt.figure(figsize=(10, 6))

plt.bar(
    season_usage["season"],
    season_usage["registered"],
    label="Registered",
    color="blue"
)

plt.bar(
    season_usage["season"],
    season_usage["casual"],
    label="Casual",
    color="red"
)

plt.xlabel(None)
plt.ylabel(None)
plt.title("Jumlah penyewaan sepeda berdasarkan musim")
plt.legend()
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
#Statistik Rental Sepeda dalam 2 Tahun
rent_year = day_df.groupby("yr", observed=False)[["cnt"]].sum().reset_index()

plt.figure(figsize=(10, 6))

plt.bar(
    rent_year["yr"],
    rent_year["cnt"],
    color= "blue",
    label="2011 - 2012"
)

plt.xlabel(None)
plt.ylabel(None)
plt.title("Jumlah Penyewaan Sepeda Berdasarkan Tahun")
plt.legend()
plt.show()

# %% [markdown]
# **Insight:**
# - Penyewaan musim tertinggi pada terdapat pada musim Falls
# - Terjadi kenaikan pada tahun 2011 sampai 2012

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
